# %% [markdown]
# # Teste de Normalidade

# %% [markdown]
# Estatistica Parametrica: Os dados estão normalizados
# Estatistica Não Parametrica: Os dados estão em distribuições diferentes de normal

# %%
import seaborn as sns

# %%
from scipy import stats
dados_normais = stats.norm.rvs(size = 1000)
dados_nao_normais = stats.skewnorm.rvs(a = 10, size = 1000)

# %%
sns.distplot(dados_normais)
# Out:
# C:\Users\daniel.nery\AppData\Local\Temp\ipykernel_9540\2411507961.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dados_normais)
# <AxesSubplot: ylabel='Density'>

# %%
sns.distplot(dados_nao_normais)
# Out:
# C:\Users\daniel.nery\AppData\Local\Temp\ipykernel_9540\767285582.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dados_nao_normais)
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# ## Quantile-quantile plot

# %%
from statsmodels.graphics.gofplots import qqplot

# %%
qqplot(dados_normais, line="s")

# %%
qqplot(dados_nao_normais, line="s")

# %% [markdown]
# ## Teste de Shapiro-Wilk
#
# - p-value é usado para interpretar o teste estatístico
# - p <= alpha: rejeita a hipótese, não é normal
# - p > alpha: não rejeita a hipótese, é normal

# %%
from scipy.stats import shapiro

# %%
_, p = shapiro(dados_normais)
p
# Out:
# 0.19809532165527344

# %%
alpha = 0.05
if p > alpha:
    print("distribuição normal")
else:
    print("distribuição não normal")
# Out:
# distribuição normal

# %%
_, p = shapiro(dados_nao_normais)
p
# Out:
# 9.538564086525908e-20

# %%
alpha = 0.05
if p > alpha:
    print("distribuição normal")
else:
    print("distribuição não normal")
# Out:
# distribuição não normal
