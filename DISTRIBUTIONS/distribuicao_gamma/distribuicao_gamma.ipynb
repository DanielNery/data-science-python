# %%
from scipy.stats import gamma
import seaborn as sns

# %%
dados_gamma = gamma.rvs(a = 1, size=1000)

# %%
dados_gamma
# Out:
# array([6.04539047e-01, 2.32620024e-01, 1.38505330e-01, 2.09543667e-01,
#        2.28659059e+00, 2.65893169e+00, 2.59214211e+00, 4.17206112e-01,
#        1.35263631e+00, 1.33854047e+00, 6.79360076e-01, 2.12906826e+00,
#        2.67096582e+00, 6.28780176e-01, 1.21398637e+00, 2.29113913e-01,
#        1.37236801e+00, 1.62625145e+00, 5.31670318e-01, 1.73740386e-01,
#        2.52471380e+00, 1.16506883e+00, 1.83955265e+00, 1.11802319e+00,
#        4.05803349e-01, 9.71124977e-02, 1.38347017e-02, 1.78437054e+00,
#        8.31765437e-01, 2.48311867e-01, 6.69921204e-01, 9.12050279e-01,
#        4.62959989e-01, 1.05531537e+00, 7.67940816e-01, 1.41394152e+00,
#        5.59316120e-01, 1.18024118e-01, 7.02057645e-02, 1.43282629e-01,
#        1.49127661e-01, 6.60826298e-01, 8.61666666e-01, 1.35417186e+00,
#        8.03890624e-01, 1.59074021e+00, 9.36578461e-01, 3.79067095e-01,
#        2.97576168e-01, 2.65651281e-01, 3.24732058e-01, 1.67496224e+00,
# ...

# %%
sns.distplot(dados_gamma)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_85572\2166762383.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dados_gamma)
# <AxesSubplot: ylabel='Density'>
